# %% [markdown]
# # Vision Transformer（ViT）
#
# Vision Transformer（ViT）是一种基于Transformer架构的图像分类模型。它将图像划分为固定大小的`块`（patches），并将这些块视为序列输入到Transformer中，通过自注意力机制捕捉图像中的全局依赖关系，从而实现高效的图像分类，以至于各种视觉任务。
#
# 与传统的卷积神经网络（CNN）不同，ViT不依赖于卷积操作，而是直接使用Transformer架构来处理图像数据。这使得ViT能够**高效地建模图像中远距离区域的依赖关系**，从而更好地捕捉图像中的全局信息，在大规模数据集上表现出色。
